# %%
import matplotlib.pyplot as plt #load the plotting library for pictures
img = plt.imread('./cat.png') #load a cat picture
plt.imshow(img); #show the cat picture

# %%
import numpy as np #load the numpy library
np.shape(img) #lets see the shape of the image
# Out:
# (512, 512, 3)

# %% [markdown]
# As we can see the image size is 512X512X3.
#
# What does it mean?
#
# It means 512 pixels down and across and 3 layers (red,green, and blue)

# %%
#lets look at a tiny fraction of the image:
plt.imshow(img[300:310,300:310]); #we choose 10 pixels down and across in the middle of the image

# %%
img[300:310,300:310,2] #these pixels have numerical values between 0-1
#try to guess if 0 is black or white, what abouot 1?
# Out:
# array([[0.19215687, 0.42352942, 0.39607844, 0.3647059 , 0.3882353 ,
#         0.4       , 0.46666667, 0.63529414, 0.69803923, 0.70980394],
#        [0.08627451, 0.12156863, 0.27450982, 0.2509804 , 0.28235295,
#         0.3882353 , 0.4392157 , 0.5137255 , 0.63529414, 0.6862745 ],
#        [0.07843138, 0.08235294, 0.12156863, 0.16078432, 0.23137255,
#         0.31764707, 0.47058824, 0.5882353 , 0.6431373 , 0.65882355],
#        [0.11764706, 0.11764706, 0.12941177, 0.13333334, 0.23137255,
#         0.2901961 , 0.30980393, 0.4117647 , 0.5176471 , 0.5764706 ],
#        [0.14901961, 0.16078432, 0.1764706 , 0.27450982, 0.29803923,
#         0.23921569, 0.21960784, 0.3254902 , 0.41568628, 0.4862745 ],
#        [0.14117648, 0.25882354, 0.40392157, 0.3529412 , 0.2784314 ,
#         0.2784314 , 0.30980393, 0.3647059 , 0.3254902 , 0.3882353 ],
#        [0.28627452, 0.30980393, 0.25882354, 0.34509805, 0.3882353 ,
#         0.37254903, 0.3647059 , 0.42352942, 0.49803922, 0.45882353],
# ...
